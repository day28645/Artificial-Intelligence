# %% [markdown]
# <a href="https://colab.research.google.com/github/day28645/Artificial-Intelligence/blob/main/week9_ann.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # No activation function

# %% [markdown]
# ## learning rate = 0.1

# %%
import tensorflow as tf
import numpy as np

# %%
X = np.array([1, 3, 5, 8],  dtype=float)
Y = np.array([5, 9, 18, 25],  dtype=float)

# %%
l0 = tf.keras.layers.Dense(units=1, input_shape=[1], activation= None)

# %%
model = tf.keras.Sequential([l0])

# %%
model.compile(loss='mean_squared_error',
              optimizer=tf.keras.optimizers.Adam(0.1))

# %%
history = model.fit(X, Y, epochs=500, verbose=False)
print("Finished training the model")
# Out:
# Finished training the model

# %%
import matplotlib.pyplot as plt
plt.xlabel('Epoch Number')
plt.ylabel("Loss Magnitude")
plt.plot(history.history['loss'])

# %% [markdown]
# ## learning rate = 0.01

# %%
model.compile(loss='mean_squared_error',
              optimizer=tf.keras.optimizers.Adam(0.01))

# %%
history = model.fit(X, Y, epochs=500, verbose=False)
print("Finished training the model")
# Out:
# Finished training the model

# %%
import matplotlib.pyplot as plt
plt.xlabel('Epoch Number')
plt.ylabel("Loss Magnitude")
plt.plot(history.history['loss'])

# %% [markdown]
# ## learning rate = 0.001

# %%
model.compile(loss='mean_squared_error',
              optimizer=tf.keras.optimizers.Adam(0.001))

# %%
history = model.fit(X, Y, epochs=500, verbose=False)
print("Finished training the model")
# Out:
# Finished training the model

# %%
import matplotlib.pyplot as plt
plt.xlabel('Epoch Number')
plt.ylabel("Loss Magnitude")
plt.plot(history.history['loss'])

# %% [markdown]
# # Sigmoid activation function

# %% [markdown]
# ## learning rate = 0.1

# %%
l0 = tf.keras.layers.Dense(units=1, input_shape=[1], activation= 'sigmoid')

# %%
model = tf.keras.Sequential([l0])

# %%
model.compile(loss='mean_squared_error',
              optimizer=tf.keras.optimizers.Adam(0.1))

# %%
history = model.fit(X, Y, epochs=500, verbose=False)
print("Finished training the model")
# Out:
# Finished training the model

# %%
import matplotlib.pyplot as plt
plt.xlabel('Epoch Number')
plt.ylabel("Loss Magnitude")
plt.plot(history.history['loss'])

# %% [markdown]
# ## learning rate = 0.01

# %%
model.compile(loss='mean_squared_error',
              optimizer=tf.keras.optimizers.Adam(0.01))

# %%
history = model.fit(X, Y, epochs=500, verbose=False)
print("Finished training the model")
# Out:
# Finished training the model

# %%
import matplotlib.pyplot as plt
plt.xlabel('Epoch Number')
plt.ylabel("Loss Magnitude")
plt.plot(history.history['loss'])

# %% [markdown]
# ## learning rate = 0.001

# %%
model.compile(loss='mean_squared_error',
              optimizer=tf.keras.optimizers.Adam(0.001))

# %%
history = model.fit(X, Y, epochs=500, verbose=False)
print("Finished training the model")
# Out:
# Finished training the model

# %%
import matplotlib.pyplot as plt
plt.xlabel('Epoch Number')
plt.ylabel("Loss Magnitude")
plt.plot(history.history['loss'])
