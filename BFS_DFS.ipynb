# %% [markdown]
# <a href="https://colab.research.google.com/github/day28645/Artificial-Intelligence/blob/main/BFS_DFS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Breadth First Search (BFS)

# %% [markdown]
# ## BFS_Picture

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## BFS_Source_Code

# %%
graph = {
  '5' : ['3','7'],
  '3' : ['2', '4'],
  '7' : ['8'],
  '2' : [],
  '4' : ['8'],
  '8' : []
}

visited = [] # List for visited nodes.
queue = []     #Initialize a queue

def bfs(visited, graph, node): #function for BFS
  visited.append(node)
  queue.append(node)

  while queue:          # Creating loop to visit each node
    m = queue.pop(0)
    print (m, end = " ")

    for neighbour in graph[m]:
      if neighbour not in visited:
        visited.append(neighbour)
        queue.append(neighbour)

# Driver Code
print("Following is the Breadth-First Search")
bfs(visited, graph, '5')    # function calling
# Out:
# Following is the Breadth-First Search
# 5 3 7 2 4 8

# %% [markdown]
# ## BFS_Picture_Assignment

# %% [markdown]
# ![BFS.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Solution**
#
# FIFO - Frankfurt > Mannheim > Würzburg > Kassel > Karlsruhe > Erfurt > Nümberg > München

# %% [markdown]
# ## BFS_Source_Code_Assignment

# %%
graph = {
  'Frankfurt' : ['Mannheim','Würzburg','Kassel'],
  'Mannheim' : ['Karlsruhe'],
  'Karlsruhe' : ['Augsburg'],
  'Augsburg' : ['München'],
  'Würzburg' : ['Erfurt','Nümberg'],
  'Erfurt' : [],
  'Nümberg' : ['Stuttgart','München'],
  'Stuttgart' : [],
  'Kassel' : ['München'],
  'München' : ['Augsburg','Nümberg','Kassel'],
}

visited = [] # List for visited nodes.
queue = []     #Initialize a queue

def bfs(visited, graph, node): #function for BFS
  visited.append(node)
  queue.append(node)

  while queue:          # Creating loop to visit each node
    m = queue.pop(0)
    print (m, end = " ")

    for neighbour in graph[m]:
      if neighbour not in visited:
        visited.append(neighbour)
        queue.append(neighbour)

# Driver Code
print("Following is the Breadth-First Search")
bfs(visited, graph, 'Frankfurt')    # function calling
# Out:
# Following is the Breadth-First Search
# Frankfurt Mannheim Würzburg Kassel Karlsruhe Erfurt Nümberg München Augsburg Stuttgart

# %% [markdown]
# # Depth First Seach (DFS)

# %% [markdown]
# ## DFS_Picture

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## DFS_Source_Code

# %%
graph = {
  '5' : ['3','7'],
  '3' : ['2', '4'],
  '7' : ['8'],
  '2' : [],
  '4' : ['8'],
  '8' : []
}

visited = set() # Set to keep track of visited nodes of graph.

def dfs(visited, graph, node):  #function for dfs
    if node not in visited:
        print (node)
        visited.add(node)
        for neighbour in graph[node]:
            dfs(visited, graph, neighbour)

# Driver Code
print("Following is the Depth-First Search")
dfs(visited, graph, '5')
# Out:
# Following is the Depth-First Search
# 5
# 3
# 2
# 4
# 8
# 7

# %% [markdown]
# ## DFS_Picture_Assignment

# %% [markdown]
# ![DFS.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Solution**
#
# LIFO - Frankfurt > Mannheim > Karlsruhe > Augsburg > München

# %% [markdown]
# ## DFS_Source_Code_Assignment

# %%
graph = {
  'Frankfurt' : ['Mannheim','Würzburg','Kassel'],
  'Mannheim' : ['Karlsruhe'],
  'Karlsruhe' : ['Augsburg'],
  'Augsburg' : ['München'],
  'Würzburg' : ['Erfurt','Nümberg'],
  'Erfurt' : [],
  'Nümberg' : ['Stuttgart','München'],
  'Stuttgart' : [],
  'Kassel' : ['München'],
  'München' : ['Augsburg','Nümberg','Kassel'],
}

visited = set() # Set to keep track of visited nodes of graph.

def dfs(visited, graph, node):  #function for dfs
    if node not in visited:
        print (node)
        visited.add(node)
        for neighbour in graph[node]:
            dfs(visited, graph, neighbour)

# Driver Code
print("Following is the Depth-First Search")
dfs(visited, graph, 'Frankfurt')
# Out:
# Following is the Depth-First Search
# Frankfurt
# Mannheim
# Karlsruhe
# Augsburg
# München
# Nümberg
# Stuttgart
# Kassel
# Würzburg
# Erfurt

# %% [markdown]
# # Uniformed Search (UFS)

# %% [markdown]
# ## UFS_Picture_Assignment

# %% [markdown]
# ![UFS.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Solution**
#
# Frankfurt > Mannheim > Augsburg > München
#
# 85 + 80 + 250 + 84 = 499

# %% [markdown]
# # Pros and Cons of Search Alogorithm (BFS, DFS, UCS)

# %% [markdown]
# ## Criteria of Search Algorithm

# %% [markdown]
# 1. optimality (cost)
# 2. completeness (solution)
# 3. time complexity (big O)
# 4. space complexity (memory)

# %% [markdown]
# ## BFS

# %% [markdown]
# *   Pros
# 1. The solution will definitely found out by BFS If there is some solution.
# 2. BFS will never get trapped in a blind alley, which means unwanted nodes.
# 3. If there is more than one solution then it will find a solution with minimal steps.
# *   Cons
# 1. Memory Constraints As it stores all the nodes of the present level to go for the next level.
# 2. If a solution is far away then it consumes time.
#
# Reference - https://medium.com/@vatsalunadkat/advantages-and-disadvantages-of-ai-algorithms-d8fb137f4df2

# %% [markdown]
# ## DFS

# %% [markdown]
# *   Pros
# 1. The memory requirement is Linear WRT Nodes.
# 2. Less time and space complexity rather than BFS.
# 3. The solution can be found out without much more search.
# *   Cons
# 1. Not Guaranteed that it will give you a solution.
# 2. Cut-off depth is smaller so time complexity is more.
# 3. Determination of depth until the search has proceeded.
#
# Reference - https://medium.com/@vatsalunadkat/advantages-and-disadvantages-of-ai-algorithms-d8fb137f4df2

# %% [markdown]
# ## UCS

# %% [markdown]
# *   Pros
#
# 1. It helps to find the path with the lowest cumulative cost inside a weighted graph having a different cost associated with each of its edge from the root node to the destination node.
# 2. It is considered to be an optimal solution since, at each state, the least path is considered to be followed.
# *   Cons
# 1. The open list is required to be kept sorted as priorities in priority queue needs to be maintained.
# 2. The storage required is exponentially large.
# 3. The algorithm may be stuck in an infinite loop as it considers every possible path going from the root node to the destination node.
#
# Reference - https://www.educba.com/uniform-cost-search/
