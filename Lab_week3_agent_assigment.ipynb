# %% [markdown]
# <a href="https://colab.research.google.com/github/day28645/Artificial-Intelligence/blob/main/Lab_week3_agent_assigment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Vacuum Agent

# %% [markdown]
# ![Vacuum Agent.png](data:image/png;base64,...)

# %% [markdown]
# #My Vacuum Agent

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# https://github.com/Laksheeta/Simple-Reflex-Vaccum-Agent/blob/main/vacuum.ipynb

# %%
import random


class Environment(object):
    def __init__(self):
        self.locationCondition = {'A': '0', 'B': '0'}
        self.locationCondition['A'] = random.randint(0, 1)
        self.locationCondition['B'] = random.randint(0, 1)


class SimpleReflexVacuumAgent(Environment):
    def __init__(self, Environment):
        print (Environment.locationCondition)
        Score = 0
        vacuumLocation = random.randint(0, 1)
        if vacuumLocation == 0:
            print ("Vacuum is randomly placed at Location A.")
            print ("Location A is Dirty.") if Environment.locationCondition['A'] == 1 else print("Location A is Clean.")
            if Environment.locationCondition['A'] == 1:
                Environment.locationCondition['A'] = 0
                Score += 1
                print ("Location A has been Cleaned.")
            print ("Moving to Location B...")
            print ("Location B is Dirty.") if Environment.locationCondition['B'] == 1 else print("Location B is Clean.")
            if Environment.locationCondition['B'] == 1:
                Environment.locationCondition['B'] = 0;
                Score += 1
                print ("Location B has been Cleaned.")
            print("Environment is Clean.")

        elif vacuumLocation == 1:
            print ("Vacuum randomly placed at Location B.")
            print ("Location B is Dirty.") if Environment.locationCondition['B'] == 1 else print("Location B is Clean.")
            if Environment.locationCondition['B'] == 1:
                Environment.locationCondition['B'] = 0
                Score += 1
                print ("Location B has been Cleaned.")
            print ("Moving to Location A...")
            print ("Location A is Dirty.") if Environment.locationCondition['A'] == 1 else print("Location A is Clean.")
            if Environment.locationCondition['A'] == 1:
                Environment.locationCondition['A'] = 0;
                Score += 1
                print ("Location A has been Cleaned.")
            print("Environment is Clean.")

        print (Environment.locationCondition)
        print ("Performance Measurement: " + str(Score))


theEnvironment = Environment()
theVacuum = SimpleReflexVacuumAgent(theEnvironment)
# Out:
# {'A': 1, 'B': 1}
# Vacuum randomly placed at Location B.
# Location B is Dirty.
# Location B has been Cleaned.
# Moving to Location A...
# Location A is Dirty.
# Location A has been Cleaned.
# Environment is Clean.
# {'A': 0, 'B': 0}
# Performance Measurement: 2

# %% [markdown]
# #Environment Terminology

# %% [markdown]
# * Full Observable
# * Single Agent
# * Deterministic
# * Discrete
# * Benign
# * Static
# * Episodic

# %% [markdown]
# # Assignment

# %% [markdown]
# ## 1.Bidding on items at an auction

# %% [markdown]
# ###My Bidding Agent

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Environment Terminology

# %% [markdown]
# * Full Observable
# * Single Agent
# * Stochastic
# * Discrete
# * Adversarial
# * Dynamic
# * Sequential

# %% [markdown]
# ## 2.Playing Soccer

# %% [markdown]
# ###My Soccer Agent

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Environment Terminology

# %% [markdown]
# * Full Observable
# * Multiple Agent
# * Stochastic
# * Discrete
# * Adversarial
# * Dynamic
# * Sequential

# %% [markdown]
# ## 3.Shopping for a watch on the internet

# %% [markdown]
# ###My Shopping Agent

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Environment Terminology

# %% [markdown]
# * Full Observable
# * Single Agent
# * Deterministic
# * Discrete
# * Adversarial
# * Static
# * Adversarial

# %% [markdown]
# ## 4.Practicing tennis against a wall

# %% [markdown]
# ###My Tennis Agent

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Environment Terminology

# %% [markdown]
# * Partially Observable
# * Single Agent
# * Stochastic
# * Continuous
# * Benign
# * Dynamic
# * Sequential
